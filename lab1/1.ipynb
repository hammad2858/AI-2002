# %%
#task1 
username = input('enter username : ')
password = input('enter password : ')
age = int(input('enter age : '))


user_data = {
    'username': username,
    'password': password,
    'age': age
}


print('User Info')
for key, value in user_data.items():
    print(f"{key}: {value}")


print('account status : ')
if age >= 13:
    print('you are allowed to create an account')
else:
    print('you are not allowed to create an account')
# Out:
# User Info
# username: hammad123
# password: pakistan123345
# age: 20
# account status :
# you are allowed to create an account

# %%
#task2
str = input('enter a string : ')
print('entered string was' , str)
print('2nd character',str[1])
print('second last character',str[-2])
print('len of str',len(str))
print('UpperCase',str.upper())
print("number of word",len(str.split()))
